# %%
import pickle
import pandas as pd

# %%
pipe = pickle.load(open('pipe.pkl','rb'))

# %%
test_input = pd.DataFrame({
'age':[50],
'gender':['male'],
'subscription_type':['Premium'],
'watch_hours':[25.98],
'last_login_days':[37],
'region':['Oceania'],
'device':['Tablet'],
'monthly_fee':[17.99],
'payment_method':['PayPal'],
'number_of_profiles':[5],
'avg_watch_time_per_day':[0.68]
})

# %%
pipe.predict(test_input)
# Out:
# array([0])
